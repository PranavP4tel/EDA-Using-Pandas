# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r".\Excel files\Marathon.csv")
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_10520\3417076420.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r".\Excel files\Marathon.csv")

# %%
print(df.head())
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance        Athlete club  \
# 0                         22           4:51:39 h               Tnfrc
# 1                         22           5:15:45 h  Roberto Echeverría
# 2                         22           5:16:44 h   Puro Trail Osorno
# 3                         22           5:34:13 h            Columbia
# 4                         22           5:54:14 h      Baguales Trail
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# ...

# %%
#Filtering data for race length as 50km or 50mi, events held in USA and in the year 2020

df1  = df[(df["Event distance/length"].isin(["50km","50mi"])) & (df["Year of event"] == 2020) & (df["Event name"].str.split("(").str.get(1).str.split(")").str.get(0) == "USA") ]

# %%
print(df1.head())
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# ...

# %%
df1.shape
# Out:
# (26090, 13)

# %%
#Removing (USA) from event name

# %%
df1["Event name"] = df1["Event name"].str.split("(").str.get(0)
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_10520\1059072359.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Event name"] = df1["Event name"].str.split("(").str.get(0)

# %%
print(df1.head())
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %%
#Creating up athlete age

# %%
df1["Athlete Age"] = df1["Year of event"] - df1["Athlete year of birth"]
# Out:
# C:\Users\prana\AppData\Local\Temp\ipykernel_10520\133175787.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Athlete Age"] = df1["Year of event"] - df1["Athlete year of birth"]

# %%
print(df1.head())
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
# ...

# %%
df2 = df1.copy()

# %%
#Removing hours from athlete performance
df2["Athlete performance"] = df2["Athlete performance"].str.split(" ").str.get(0)

# %%
df2.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
#Dropping columns: Athlete club, country, and year of birth, Athlete age category
df3 = df2.drop(["Athlete club","Athlete country","Athlete year of birth","Athlete age category"],axis = 1)
df3.head()
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20             3:17:55
# 2539946                  50km                         20             4:02:32
# 2539947                  50km                         20             4:07:57
# 2539948                  50km                         20             4:22:02
# 2539949                  50km                         20             4:27:34
#
# ...

# %%
df3.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# Athlete Age                  233
# dtype: int64

# %%
df3[df3["Athlete Age"].isna()]
# Out:
#          Year of event Event dates                           Event name  \
# 2547794           2020  25.01.2020        North Carolina Fat Ass 50 Km
# 2551331           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551336           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551344           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# 2551348           2020  19.01.2020      Big Bend 50 - Fresno Creek 50K
# ...                ...         ...                                  ...
# 2746543           2020  17.10.2020     Black River Trail Classic 50 Km
# 2749869           2020  17.10.2020  MuleSkinner Endurance 50 Mile Race
# 2755985           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755994           2020  10.10.2020      Man Against Horse 50 Mile Race
# 2755997           2020  10.10.2020      Man Against Horse 50 Mile Race
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#dropping null values
df3 = df3.dropna()

# %%
df3.shape
# Out:
# (25857, 10)

# %%
#check for duplicates
df3[df3.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, Athlete Age]
# Index: []

# %%
#Reset index
df3.reset_index(drop=True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 25852           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25853           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25854           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25855           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 25856           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %%
#Correcting data types
df3["Athlete Age"] = df3["Athlete Age"].astype(int)

# %%
df3["Athlete average speed"] = df3["Athlete average speed"].astype(float)

# %%
df3.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# Athlete Age                    int32
# dtype: object

# %%
df3 = df3.rename(columns = {'Year of event':'year',
                            'Event dates':'date',
                            'Event name':'name',
                            'Event distance/length':'distance',
                            'Event number of finishers':'finishers',
                            'Athlete performance':'performance',
                            'Athlete gender':'gender',
                            'Athlete average speed':'avg_speed',
                            'Athlete ID':'id',
                            'Athlete Age':'age'
                           })

# %%
df3.head()
# Out:
#          year        date                                      name distance  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition      50km
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition      50km
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition      50km
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition      50km
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition      50km
#
#          finishers performance gender  avg_speed      id  age
# 2539945         20     3:17:55      M     15.158   71287   29
# 2539946         20     4:02:32      M     12.369  629508   39
# 2539947         20     4:07:57      M     12.099   64838   21
# 2539948         20     4:22:02      M     11.449  704450   37
# 2539949         20     4:27:34      M     11.212  810281   43

# %%
#reorder columns
df4 = df3[['date','name','distance','finishers','id','gender','age','performance','avg_speed','year']]

# %%
df4.head()
# Out:
#                date                                      name distance  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition      50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition      50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition      50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition      50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition      50km
#
#          finishers      id gender  age performance  avg_speed  year
# 2539945         20   71287      M   29     3:17:55     15.158  2020
# 2539946         20  629508      M   39     4:02:32     12.369  2020
# 2539947         20   64838      M   21     4:07:57     12.099  2020
# 2539948         20  704450      M   37     4:22:02     11.449  2020
# 2539949         20  810281      M   43     4:27:34     11.212  2020

# %%
#Count of races as 50km or 50 mi
sns.histplot(df4['distance'])
# Out:
# <Axes: xlabel='distance', ylabel='Count'>

# %%
#Distribution of average speed of athletes for 50mi races
sns.histplot(df4[df4["distance"] == "50mi"]["avg_speed"])
# Out:
# <Axes: xlabel='avg_speed', ylabel='Count'>

# %%
#Distribution of average speed of athleted for different race lengths, categorized by gender
sns.boxplot(df4,x = 'distance',y = 'avg_speed',hue = "gender")
# Out:
# <Axes: xlabel='distance', ylabel='avg_speed'>

# %%
#Distribution of average speed of atheletes of different ages, categorized by gender
sns.lmplot(df4,x = 'age',y='avg_speed',hue = 'gender')

# %%
#Difference in speed for males and females

# %%
df4.groupby(['distance','gender'])['avg_speed'].mean()
# Out:
# distance  gender
# 50km      F         7.083011
#           M         7.738985
# 50mi      F         6.834371
#           M         7.257633
# Name: avg_speed, dtype: float64

# %%
#age groups performing best in 50 m race (count 20 and above)
df4.query('distance == "50mi"').groupby('age')['avg_speed'].agg(['mean','count']).sort_values('mean',ascending = False).query('count>19')
# Out:
#          mean  count
# age
# 29   7.902252    135
# 23   7.779800     55
# 28   7.575252    107
# 30   7.569204    157
# 25   7.540923     91
# 31   7.451638    138
# 38   7.430022    231
# 35   7.422359    195
# 36   7.403854    185
# 26   7.379800     75
# 33   7.379188    149
# 22   7.367902     41
# 24   7.354274     73
# 42   7.327656    209
# 34   7.319011    182
# 40   7.310669    236
# 21   7.304658     38
# 20   7.293778     27
# 32   7.287969    162
# 39   7.283648    227
# 37   7.220493    221
# 27   7.201748    119
# 41   7.197017    179
# 45   7.130667    156
# 47   7.085410    156
# 44   7.052642    179
# 51   7.019379    124
# 46   6.897236    174
# 43   6.884225    187
# 52   6.847400    130
# 55   6.828623     69
# 54   6.805506     83
# 49   6.789553    159
# 57   6.783205     78
# 53   6.736969     96
# 56   6.708373     67
# 48   6.696853    136
# 59   6.672072     83
# 50   6.671541    172
# 64   6.620727     22
# 58   6.582328     67
# 63   6.514806     31
# ...

# %%
#Creating a column to indicate season in which event was held
df5 = df4.copy()
df5['month'] = df5['date'].str.split('.').str.get(1).astype(int)

# %%
df5.head()
# Out:
#                date                                      name distance  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition      50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition      50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition      50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition      50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition      50km
#
#          finishers      id gender  age performance  avg_speed  year  month
# 2539945         20   71287      M   29     3:17:55     15.158  2020      2
# 2539946         20  629508      M   39     4:02:32     12.369  2020      2
# 2539947         20   64838      M   21     4:07:57     12.099  2020      2
# 2539948         20  704450      M   37     4:22:02     11.449  2020      2
# 2539949         20  810281      M   43     4:27:34     11.212  2020      2

# %%
df5['season'] = df5['month'].apply(lambda x:'Winter' if x>11 else 'Fall' if x>8 else 'Summer' if x>5 else 'Spring' if x>2 else "Winter")

# %%
df5['season']
# Out:
# 2539945    Winter
# 2539946    Winter
# 2539947    Winter
# 2539948    Winter
# 2539949    Winter
#             ...
# 2760957      Fall
# 2760958      Fall
# 2760959      Fall
# 2760960      Fall
# 2760961      Fall
# Name: season, Length: 25857, dtype: object

# %%
df5['season'].nunique()
# Out:
# 4

# %%
#Calculating average speed of athletes categorized by seasons in which events were held
df5.groupby('season')['avg_speed'].agg(['mean','count']).sort_values('mean',ascending=False)
# Out:
#             mean  count
# season
# Spring  7.684430   3294
# Winter  7.518187  11595
# Fall    7.406619   8315
# Summer  6.869336   2653
